# %% [markdown]
# # Implementing N-grams
# * **Name:** Mohammad Mahdi Salmani

# %%
import random
import re
import nltk
from nltk import bigrams
from nltk.tokenize import word_tokenize
from collections import Counter
from collections import defaultdict

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/dataset')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Q 3.1: Load and Preprocess Dataset

# %%
def load_text_file(file_path):
    with open(file_path, 'r') as file:
        text = file.read()
    return text[1:]

def normalize_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove extra whitespaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
# Load the text file
file_path = "./data/Tarzan.txt"
raw_text = load_text_file(file_path)
normalized_text = normalize_text(raw_text)

# %%
tokenized_text = word_tokenize(normalized_text)

print(f"Tokenized text: (len={len(tokenized_text)})")
print(tokenized_text)
# Out:
# Tokenized text: (len=72974)
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'tarzan', 'lord', 'of', 'the', 'jungle', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 'reuse', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'wwwgutenbergorg', 'if', 'you', 'are', 'not', 'located', 'in', 'the', 'united', 'states', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'ebook', 'title', 'tarzan', 'lord', 'of', 'the', 'jungle', 'author', 'edgar', 'rice', 'burroughs', 'release', 'date', 'february', '12', '2024', 'ebook', '72938', 'language', 'english', 'original', 'publication', 'new', 'york', 'ny', 'grosset', 'dunlap', 'publishers', '1928', 'credits', 'greg', 'weeks', 'mary', 'meehan', 'and', 'the', 'online', 'distributed', 'proofreading', 'team', 'at', 'httpwwwpgdpnet', 'start', 'of', 'the', 'project', 'gutenberg', 'ebook', 'tarzan', 'lord', 'of', 'the', 'jungle', 'tarzan', 'lord', 'of', 'the', 'jungle', 'by', 'edgar', 'rice', 'burroughs', 'grosset', 'dunlap', '_publishers_', 'new', 'york', 'copyright', '1928', 'by', 'edgar', 'rice', 'burroughs', 'inc', '_copyright', 'renewed', '1956', 'by', 'john', 'coleman', 'burroughs_', '_all', 'rights', 'reserved_', '_printed', 'in', 'the', 'united', 'states', 'of', 'america_', '_contents_', 'tantor', 'the', 'elephant', 'comrades', 'of', 'the', 'wild', 'the', 'apes', 'of', 'toyat', 'bolgani', 'the', 'gorilla', 'the', 'tarmangani', 'ara', 'the', 'lightning', 'the', 'cross', 'the', 'snake', 'strikes', 'sir', 'richard', 'the', 'return', 'of', 'ulala', 'sir', 'james', 'tomorrow', 'thou', 'diest', 'in', 'the', 'beyt', 'of', 'zeyd', 'sword', 'and', 'buckler', 'the', 'lonely', 'grave', 'the', 'great', 'tourney', 'the', 'saracens', 'the', 'black', 'knight', 'lord', 'tarzan', 'i', 'love', 'you', 'for', 'every', 'jewel', 'a', 'drop', 'of', 'blood', 'bride', 'of', 'the', 'ape', 'jadbalja', 'where', 'trails', 'met', 'tarzan', '_lord', 'of', 'the', 'jungle_', 'chapter', 'i', '_tantor', 'the', 'elephant_', 'his', 'great', 'bulk', 'swaying', 'to', 'and', 'fro', 'as', 'he', 'threw', 'his', 'weight', 'first', 'upon', 'one', 'side', 'and', 'then', 'upon', 'the', 'other', 'tantor', 'the', 'elephant', 'lolled', 'in', 'the', 'shade', 'of', 'the', 'father', 'of', 'forests', 'almost', 'omnipotent', 'he', 'in', 'the', 'realm', 'of', 'his', 'people', 'dango', 'sheeta', 'even', 'numa', 'the', 'mighty', 'were', 'as', 'naught', 'to', 'the', 'pachyderm', 'for', 'a', 'hundred', 'years', 'he', 'had', 'come', 'and', 'gone', 'up', 'and', 'down', 'the', 'land', 'that', 'had', 'trembled', 'to', 'the', 'comings', 'and', 'the', 'goings', 'of', 'his', 'forebears', 'for', 'countless', 'ages', 'in', 'peace', 'he', 'had', 'lived', 'with', 'dango', 'the', 'hyena', 'sheeta', 'the', 'leopard', 'and', 'numa', 'the', 'lion', 'man', 'alone', 'had', 'made', 'war', 'upon', 'him', 'man', 'who', 'holds', 'the', 'unique', 'distinction', 'among', 'created', 'things', 'of', 'making', 'war', 'on', 'all', 'living', 'creatures', 'even', 'to', 'his', 'own', 'kind', 'man', 'the', 'ruthless', 'man', 'the', 'pitiless', 'man', 'the', 'most', 'hated', 'living', 'organism', 'that', 'nature', 'has', 'evolved', 'always', 'during', 'the', 'long', 'hundred', 'years', 'of', 'his', 'life', 'tantor', 'had', 'known', 'man', 'there', 'had', 'been', 'black', 'men', 'always', 'big', 'black', 'warriors', 'with', 'spears', 'and', 'arrows', 'little', 'black', 'warriors', 'swart', 'arabs', 'with', 'crude', 'muskets', 'and', 'white', 'men', 'with', 'powerful', 'express', 'rifles', 'and', 'elephant', 'guns', 'the', 'white', 'men', 'had', 'been', 'the', 'last', 'to', 'come', 'and', 'were' ...

# %% [markdown]
# ## Q 3.2: Implementing Bigram

# %%
nltk.download('punkt')

# %%
def calculate_unigram_counts(tokenized_text):
    unigram_counts = Counter(tokenized_text)
    return unigram_counts

def calculate_bigram_counts(tokenized_text):
    bi_grams = list(bigrams(tokenized_text))
    bigram_counts = Counter(bi_grams)
    return bigram_counts

# %%
unigram_counts = calculate_unigram_counts(tokenized_text)
print('Unigrams:',unigram_counts)
bigram_counts = calculate_bigram_counts(tokenized_text)
print('Bigrams:',bigram_counts)
# Out:
# Unigrams: Counter({'the': 5548, 'of': 2562, 'and': 2444, 'to': 1618, 'he': 1509, 'a': 1341, 'his': 1071, 'that': 1068, 'in': 940, 'was': 845, 'had': 626, 'him': 613, 'it': 595, 'with': 588, 'for': 568, 'not': 558, 'i': 556, 'you': 510, 'as': 489, 'but': 462, 'they': 431, 'from': 413, 'blake': 411, 'be': 404, 'upon': 385, 'at': 383, 'were': 350, 'tarzan': 331, 'them': 304, 'is': 294, 'have': 291, 'by': 291, 'this': 265, 'their': 256, 'said': 253, 'there': 249, 'sir': 240, 'ibn': 238, 'thou': 235, 'would': 230, 'jad': 226, 'no': 222, 'one': 218, 'her': 213, 'great': 209, 'who': 209, 'or': 208, 'what': 207, 'we': 205, 'man': 203, 'an': 193, 'all': 182, 'stimbol': 181, 'she': 180, 'into': 175, 'when': 173, 'been': 170, 'are': 168, 'knights': 166, 'so': 156, 'me': 155, 'which': 154, 'could': 153, 'if': 150, 'will': 149, 'then': 147, 'before': 146, 'do': 144, 'nimmr': 143, 'where': 140, 'men': 137, 'did': 136, 'on': 135, 'my': 130, 'knight': 129, 'about': 129, 'two': 128, 'fahd': 123, 'through': 120, 'now': 118, 'toward': 113, 'out': 113, 'jungle': 108, 'other': 107, 'came': 107, 'thee': 107, 'saw': 106, 'back': 104, 'know': 103, 'richard': 100, 'again': 99, 'more': 97, 'eyes': 96, 'cried': 95, 'well': 94, 'replied': 93, 'guinalda': 93, 'come': 91, 'might': 90, 'demanded': 90, 'project': 89, 'apeman': 88, 'while': 88, 'malud': 88, 'gutenberg': 87, 'down': 87, 'thy': 87, 'sepulcher': 87, 'black': 86, 'us': 86, 'any': 86, 'your': 85, 'zeyd': 84, 'than': 83, 'own': 82, 'way': 82, 'turned': 81, 'may': 79, 'up': 78, 'here': 78, 'am': 77, 'first': 76, 'side': 76, 'shall': 76, 'apes': 75, 'see': 75, 'must': 75, 'tollog': 75, 'country': 74, 'many': 74, 'valley': 73, 'even': 72, 'tell': 72, 'trail': 72, 'away': 71, 'too': 71, 'knew': 71, 'time': 71, 'lay': 70, 'head': 70, 'only': 70, 'these': 70, 'city': 70, 'himself': 70, 'its': 70, 'far': 69, 'against': 69, 'long': 68, 'james': 67, 'asked': 64, 'ateja': 64, 'gobred': 64, 'people': 63, 'another': 63, 'go': 63, 'just': 63, 'sheik': 62, 'some': 62, 'until': 62, 'old': 62, 'thought': 61, 'within': 61, 'blakes': 61, 'day': 59, 'those': 59, 'fejjuan': 59, 'over': 59, 'can': 59, 'prince': 59, 'beyt': 58, 'nasrany': 58, 'nor': 58, 'heard': 58, 'behind': 57, 'should': 57, 'princess': 57, 'our': 56, 'after': 56, 'bohun': 56, 'north': 55, 'young': 55, 'without': 54, 'take': 54, 'girl': 54, 'camp': 54, 'castle': 54, 'days': 53, 'hand': 53, 'left': 53, 'sword': 52, 'lion': 51, 'stood': 51, 'though': 51, 'among': 50, 'others': 50, 'face': 50, 'held': 50, 'almost': 49, 'hundred': 49, 'made': 48, 'work': 48, 'find': 48, 'how': 48, 'once': 47, 'night': 47, 'white': 46, 'seen': 46, 'ground': 46, 'never': 46, 'looked': 46, 'like': 46, 'king': 46, 'return': 45, 'galla': 45, 'art': 45, 'found': 45, 'close': 45, 'treasure': 45, 'perhaps': 44, 'passed': 44, 'kill': 44, 'lists': 44, 'buckler': 43, 'little': 43, 'menzil': 43, 'much': 43, 'still': 43, 'has': 42, 'yet': 42, 'few': 42, 'followed': 42, 'village': 42, 'thus': 42, 'good': 42, 'off': 41, 'raised': 41, 'hath': 41, 'being': 41, 'along': 41, 'lance': 41, 'life': 40, 'because': 40, 'make': 40, 'carried': 40, 'rode': 40, 'since': 39, 'let': 39, 'dead': 39, 'feet': 39, 'food': 39, 'horse': 39, 'tourney': 38, 'exclaimed': 38, 'across': 38, 'took': 38, 'full': 38, 'such': 38, 'new': 37, 'didst': 37, 'direction': 37, 'ever': 37, 'right': 37, 'toyat': 36, 'bolgani': 36, 'always': 36, 'last': 36, 'why': 36, 'brother': 36, 'end': 36, 'forest': 35, 'friend': 35, 'aarab': 35, 'beneath': 35, 'set': 35, 'party': 35, 'lord': 34, 'above': 34, 'between': 34, 'forward': 34, 'presently': 34, 'company': 34, 'moment': 34, 'get': 34, 'most': 33, 'sat': 33, 'very': 33, 'felt': 33, 'going': 33, 'love': 32, 'half': 32, 'sheykh': 32, 'friends': 32, 'three': 32, 'works': 32, 'tarmangani': 31, 'blood': 31, 'numa': 31, 'alone': 31, 'south': 31, 'instant': 31, 'say': 31, 'yes': 31, 'thing': 31, 'morning': 31, 'seemed': 31, 'american': 31, 'under': 30, 'father': 30, 'slaves': 30, 'whom' ...
# Bigrams: Counter({('of', 'the'): 966, ('in', 'the'): 371, ('to', 'the'): 312, ('ibn', 'jad'): 226, ('and', 'the'): 190, ('upon', 'the'): 162, ('from', 'the'): 156, ('he', 'had'): 151, ('of', 'his'): 134, ('of', 'a'): 124, ('that', 'he'): 124, ('he', 'was'): 119, ('it', 'was'): 118, ('at', 'the'): 117, ('into', 'the'): 115, ('with', 'the'): 113, ('of', 'nimmr'): 109, ('the', 'great'): 98, ('by', 'the'): 98, ('for', 'the'): 96, ('the', 'jungle'): 94, ('that', 'the'): 94, ('had', 'been'): 93, ('project', 'gutenberg'): 87, ('the', 'apeman'): 87, ('as', 'he'): 85, ('the', 'sepulcher'): 82, ('toward', 'the'): 81, ('did', 'not'): 75, ('he', 'said'): 75, ('through', 'the'): 74, ('the', 'knights'): 73, ('in', 'his'): 72, ('was', 'a'): 72, ('i', 'am'): 70, ('knights', 'of'): 70, ('there', 'was'): 68, ('the', 'apes'): 65, ('one', 'of'): 64, ('they', 'were'): 64, ('to', 'his'): 62, ('it', 'is'): 60, ('to', 'be'): 60, ('with', 'a'): 60, ('as', 'the'): 58, ('the', 'valley'): 58, ('and', 'his'): 57, ('tarzan', 'of'): 57, ('him', 'and'): 57, ('the', 'two'): 55, ('and', 'a'): 54, ('and', 'then'): 53, ('in', 'a'): 52, ('i', 'have'): 52, ('sir', 'richard'): 51, ('the', 'sheik'): 51, ('he', 'could'): 51, ('sir', 'james'): 50, ('he', 'would'): 50, ('the', 'trail'): 50, ('do', 'not'): 48, ('but', 'he'): 48, ('and', 'he'): 48, ('the', 'other'): 47, ('and', 'that'): 47, ('he', 'saw'): 47, ('for', 'a'): 46, ('was', 'not'): 46, ('upon', 'his'): 46, ('out', 'of'): 46, ('could', 'not'): 46, ('you', 'are'): 45, ('was', 'the'): 45, ('the', 'black'): 44, ('would', 'be'): 44, ('of', 'this'): 44, ('a', 'great'): 44, ('the', 'man'): 44, ('the', 'girl'): 44, ('the', 'lists'): 44, ('the', 'ground'): 43, ('city', 'of'): 43, ('the', 'city'): 43, ('and', 'so'): 42, ('the', 'princess'): 42, ('that', 'it'): 40, ('that', 'i'): 40, ('the', 'castle'): 40, ('they', 'had'): 39, ('the', 'first'): 39, ('sir', 'malud'): 39, ('him', 'to'): 38, ('that', 'you'): 38, ('with', 'his'): 37, ('of', 'ibn'): 37, ('who', 'had'): 37, ('that', 'they'): 37, ('and', 'as'): 37, ('that', 'had'): 36, ('his', 'own'): 36, ('when', 'he'): 36, ('of', 'them'): 35, ('the', 'beyt'): 34, ('the', 'north'): 34, ('on', 'the'): 34, ('he', 'is'): 34, ('and', 'i'): 34, ('he', 'knew'): 34, ('knew', 'that'): 34, ('the', 'project'): 33, ('his', 'eyes'): 33, ('them', 'and'): 33, ('the', 'young'): 33, ('blake', 'was'): 33, ('there', 'were'): 32, ('the', 'menzil'): 32, ('all', 'the'): 32, ('thou', 'art'): 32, ('the', 'treasure'): 32, ('at', 'a'): 32, ('have', 'been'): 32, ('before', 'the'): 32, ('if', 'you'): 31, ('and', 'in'): 31, ('the', 'men'): 31, ('when', 'the'): 31, ('would', 'have'): 30, ('he', 'did'): 30, ('will', 'be'): 30, ('upon', 'him'): 29, ('not', 'know'): 29, ('as', 'they'): 29, ('and', 'at'): 29, ('he', 'cried'): 29, ('his', 'head'): 29, ('of', 'their'): 29, ('said', 'the'): 29, ('i', 'shall'): 29, ('the', 'lion'): 28, ('a', 'few'): 28, ('the', 'same'): 28, ('the', 'aarab'): 28, ('replied', 'the'): 28, ('the', 'direction'): 28, ('to', 'him'): 27, ('across', 'the'): 27, ('and', 'there'): 27, ('of', 'him'): 27, ('blake', 'and'): 27, ('the', 'prince'): 27, ('sir', 'knight'): 27, ('princess', 'guinalda'): 27, ('of', 'tarzan'): 26, ('the', 'forest'): 26, ('we', 'shall'): 26, ('but', 'the'): 26, ('and', 'it'): 26, ('to', 'a'): 26, ('going', 'to'): 26, ('a', 'knight'): 26, ('down', 'the'): 25, ('the', 'others'): 25, ('is', 'the'): 25, ('to', 'do'): 25, ('the', 'way'): 25, ('that', 'was'): 25, ('saw', 'the'): 25, ('the', 'outer'): 25, ('at', 'his'): 25, ('with', 'them'): 24, ('is', 'a'): 24, ('back', 'to'): 24, ('he', 'will'): 24, ('you', 'have'): 24, ('then', 'he'): 24, ('from', 'his'): 24, ('the', 'south'): 24, ('the', 'village'): 24, ('knight', 'of'): 24, ('which', 'he'): 23, ('that', 'his'): 23, ('that', 'thou'): 23, ('about', 'the'): 23, ('we', 'are'): 23, ('by', 'a'): 23, ('within', 'the'): 23, ('the', 'desert'): 23, ('i', 'know'): 23, ('and', 'when'): 23, ('the', 'nasrany'): 23, ('the', 'night'):  ...

# %% [markdown]
# * Calculate bigram probablities

# %%
def calcBigramProb(unigramCounts, bigramCounts):
    bigram_probabilities = {}
    vocabulary_size = len(unigramCounts)
    for bigram, count in bigramCounts.items():
        word1, word2 = bigram[0], bigram[1]
        # # Apply add-one smoothing
        # smoothed_count = count + 1
        # # Add-one smoothing to unigram count as well
        # smoothed_unigram_count = unigramCounts[word1] + vocabulary_size
        if word1 not in bigram_probabilities:
            bigram_probabilities[word1] = {}
        bigram_probabilities[word1][word2] = count / unigramCounts[word1]
    return bigram_probabilities

# %%
tokens_len = len(tokenized_text)
unigram_probabilities = dict([(x[0],x[1]/tokens_len) for x in unigram_counts.items()])

bigram_probabilities = calcBigramProb(unigram_counts, bigram_counts)

# %%
def generate_next_token_bigram(token, bigram_probabilities):
    if token in bigram_probabilities:
        possible_next_tokens = list(bigram_probabilities[token].keys())
        weights = list(bigram_probabilities[token].values())
        return random.choices(possible_next_tokens, weights=weights)[0]
    else:
        # if bigram probablity is zero using unigram (to solve data sparsity problem)
        all_tokens = list(unigram_probabilities.keys())
        weights = list(unigram_probabilities.values())
        return random.choices(all_tokens, weights=weights)[0]

# %%
expressions = [
    "Knowing well the windings of the trail he",
    "For half a day he lolled on the huge back and"
]

# %%
# Complete expressions...
for i, expression in enumerate(expressions):
    print(f'[{i+1}] {expression}', end='  ')
    tokens = word_tokenize(normalize_text(expression))
    current_bigram = tokens[-1]
    # Generate 10 tokens
    for _ in range(10):
        next_token = generate_next_token_bigram(current_bigram, bigram_probabilities)
        print(next_token, end=' ')
        if next_token:
            tokens.append(next_token)
            current_bigram = next_token
        else:
            break
    print()
# Out:
# [1] Knowing well the windings of the trail he  aimed but as though he did not zeyd held at
# [2] For half a day he lolled on the huge back and  taken from pike and looked about the food and new

# %% [markdown]
# ## Q 3.4: Implementing Trigram:

# %%
from nltk.util import trigrams

def calculate_trigram_counts(tokenized_text):
    tri_grams = list(trigrams(tokenized_text))
    return Counter(tri_grams)

def calcTrigramProb(bigramCounts, trigramCounts):
    trigram_probabilities = {}
    for trigram, count in trigramCounts.items():
        word1, word2, word3 = trigram[0], trigram[1], trigram[2]
        if word1 not in trigram_probabilities:
            trigram_probabilities[word1] = {}
        if word2 not in trigram_probabilities[word1]:
            trigram_probabilities[word1][word2] = {}
        # # Apply add-one smoothing
        # smoothed_count = count + 1
        # smoothed_bigram_count = bigramCounts[word1][word2] + vocabulary_size
        trigram_probabilities[word1][word2][word3] = count / bigramCounts[word1][word2]
    return trigram_probabilities

def generate_next_token_trigram(trigram, trigram_probabilities):
    possible_next_tokens = [next_token for (first_token, second_token, next_token), prob in trigram_probabilities.items() if (first_token, second_token) == (trigram[-2], trigram[-1])]
    if possible_next_tokens:
        return random.choices(possible_next_tokens, weights=[trigram_probabilities[(trigram[-2], trigram[-1], next_token)] for next_token in possible_next_tokens])[0]
    else:
        return generate_next_token_bigram(trigram[-2:], bigram_probabilities)

# %%
# Train the trigram model
trigram_counts = calculate_trigram_counts(tokenized_text)
trigram_probabilities = calcTrigramProb(bigram_counts, trigram_counts)

# %%
# Complete expressions...
for i, expression in enumerate(expressions):
    tokens = word_tokenize(expression)
    current_trigram = (tokens[-3], tokens[-2], tokens[-1])
    # Generate 10 tokens
    for _ in range(10):
        next_token = generate_next_token_trigram(current_trigram, trigram_probabilities)
        if next_token:
            tokens.append(next_token)
            current_trigram = (current_trigram[-2], current_trigram[-1], next_token)
        else:
            break
    print(f'[{i+1}]', ' '.join(tokens))
# Out:
# [1] Knowing well the windings of the trail he took with seven great lions watching his slow way .
# [2] For half a day he lolled on the huge back and join me ; but once within this tent it required

# %% [markdown]
# ### Implementing N-gram:

# %%
from nltk.util import ngrams

class LanguageModel:
    def __init__(self, tokenized_text, n=5) -> None:
        self.n = n
        self.tokenized_text = tokenized_text

        unigram_counts = self.calculate_unigram_counts()
        self.unigram_probabilities = dict([(x[0],x[1]/len(tokenized_text)) for x in unigram_counts.items()])

    def calculate_unigram_counts(self):
        unigram_counts = Counter(self.tokenized_text)
        return unigram_counts

    def calculate_ngram_counts(self, n):
        n_grams = list(ngrams(self.tokenized_text, n))
        return Counter(n_grams)

    def calcNgramProb(self, n):
        n_gramCounts = self.calculate_ngram_counts(n)
        n_1_gramCounts = self.calculate_ngram_counts(n-1)

        ngram_probabilities = {}
        # vocabulary_size = len(n_1_gramCounts)
        for ngram, count in n_gramCounts.items():
            prefix = ngram[:-1]
            last_word = ngram[-1]
            # # Apply add-one smoothing
            # smoothed_count = count + 1
            # smoothed_prefix_count = ngramCounts.get(prefix, 0) + vocabulary_size
            if prefix not in ngram_probabilities:
                ngram_probabilities[prefix] = {}
            ngram_probabilities[prefix][last_word] = count / n_1_gramCounts[prefix]
        return ngram_probabilities

    def generate_next_token_ngram(self, ngram, ngram_probabilities):
        if ngram in ngram_probabilities:
            possible_next_tokens = list(ngram_probabilities[ngram].keys())
            weights = list(ngram_probabilities[ngram].values())
            return random.choices(possible_next_tokens, weights=weights)[0]
        else:
            if self.n > 3:
                n_2_gram_probs = self.calcNgramProb(self.n - 2)
                n_2_gram = tuple(ngram[2:])
                # print('\n\n*** ',n_2_gram,'\n\n') #TODO: delete this line
                return self.generate_next_token_ngram(n_2_gram, n_2_gram_probs)
            else:
                all_tokens = list(self.unigram_probabilities.keys())
                weights = list(self.unigram_probabilities.values())
                return random.choices(all_tokens, weights=weights)[0]

# %%
# Trigram model
trigram_model = LanguageModel(tokenized_text, n=3)
ngram_probabilities = trigram_model.calcNgramProb(n=3)
# Complete expressions...
print('Trigram model:')
for i, expression in enumerate(expressions):
    print(f'[{i+1}] {expression}', end='  ')
    tokens = word_tokenize(normalize_text(expression))
    current_ngram = tuple(tokens[-2:])
    # Generate 10 tokens
    for _ in range(10):
        next_token = trigram_model.generate_next_token_ngram(current_ngram, ngram_probabilities)
        print(next_token, end=' ')
        if next_token:
            tokens.append(next_token)
            current_ngram = tuple(tokens[-2:])
        else:
            break
    print()
# Out:
# Trigram model:
# [1] Knowing well the windings of the trail he  came from the ground the brute came close guinalda closed
# [2] For half a day he lolled on the huge back and  overtake you without much loss of time how long he

# %%
# Train the 5-gram model
_5_gram_model = LanguageModel(tokenized_text, n=5)
ngram_probabilities = _5_gram_model.calcNgramProb(n=5)

# %%
# Complete expressions...
print('5-gram model:')
for i, expression in enumerate(expressions):
    print(f'[{i+1}] {expression}', end='  ')
    tokens = word_tokenize(normalize_text(expression))
    current_ngram = tuple(tokens[-4:])
    # Generate 10 tokens
    for _ in range(10):
        next_token = _5_gram_model.generate_next_token_ngram(current_ngram, ngram_probabilities)
        print(next_token, end=' ')
        if next_token:
            tokens.append(next_token)
            current_ngram = tuple(tokens[-4:])
        else:
            break
    print()
# Out:
# 5-gram model:
# [1] Knowing well the windings of the trail he  took short cuts swinging through the branches of the trees
# [2] For half a day he lolled on the huge back and  join me but if she is with them youd better
